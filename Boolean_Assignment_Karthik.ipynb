# %%
# BOOLEAN DATATYPE ASSIGNMENT
# ==========================

# SOLVED EXAMPLE
# --------------
# Question: Check if a number is both even and greater than 10
print("SOLVED EXAMPLE:")
print("Check if a number is both even and greater than 10")
number = 16
is_even = number % 2 == 0
is_greater_than_10 = number > 10
result = is_even and is_greater_than_10
print(f"Number: {number}")
print(f"Is even: {is_even}")
print(f"Is greater than 10: {is_greater_than_10}")
print(f"Both conditions: {result}")
print("-" * 50)
# Out:
# SOLVED EXAMPLE:
# Check if a number is both even and greater than 10
# Number: 16
# Is even: True
# Is greater than 10: True
# Both conditions: True
# --------------------------------------------------

# %%
# ASSIGNMENT QUESTIONS
# ===================

# Question 1: Check if 25 is greater than 20 and less than 30
print("Question 1: Check if 25 is greater than 20 and less than 30")
# Your code here
number = 25
is_greater_than_20 = number > 20
is_less_than_30 = number < 30
result = is_greater_than_20 and is_less_than_30
print(f"Number: {number}")
print(f"Is greater than 20: {is_greater_than_20}")
print(f"Is less than 30: {is_less_than_30}")
print(f"Both conditions: {result}")
print("-" * 50)
# Out:
# Question 1: Check if 25 is greater than 20 and less than 30
# Number: 25
# Is greater than 20: True
# Is less than 30: True
# Both conditions: True
# --------------------------------------------------

# %%
# Question 2: Check if string "python" is equal to "Python" (case sensitive)
print("\nQuestion 2: Check if string 'python' is equal to 'Python' (case sensitive)")
# Your code here
string1 = "python"
string2 = "Python"
result = string1 == string2
print(f"String 1: {string1}")
print(f"String 2: {string2}")
print(f"Are equal: {result}")
print("-" * 50)
# Out:
# Question 2: Check if string 'python' is equal to 'Python' (case sensitive)
# String 1: python
# String 2: Python
# Are equal: False
# --------------------------------------------------

# %%
# Question 3: Check if 15 is divisible by both 3 and 5
print("\nQuestion 3: Check if 15 is divisible by both 3 and 5")
# Your code here
number = 15
is_divisible_by_3 = number % 3 == 0
is_divisible_by_5 = number % 5 == 0
result = is_divisible_by_3 and is_divisible_by_5
print(f"Number: {number}")
print(f"Is divisible by 3: {is_divisible_by_3}")
print(f"Is divisible by 5: {is_divisible_by_5}")
print(f"Both conditions: {result}")
print("-" * 50)
# Out:
# Question 3: Check if 15 is divisible by both 3 and 5
# Number: 15
# Is divisible by 3: True
# Is divisible by 5: True
# Both conditions: True
# --------------------------------------------------

# %%
# Question 4: Check if 7 is not equal to 8
print("\nQuestion 4: Check if 7 is not equal to 8")
# Your code here
number1 = 7
number2 = 8
result = number1 != number2
print(f"Number 1: {number1}")
print(f"Number 2: {number2}")
print(f"Are not equal: {result}")
print("-" * 50)
# Out:
# Question 4: Check if 7 is not equal to 8
# Number 1: 7
# Number 2: 8
# Are not equal: True
# --------------------------------------------------

# %%
# Question 5: Check if 100 is greater than 50 or less than 25
print("\nQuestion 5: Check if 100 is greater than 50 or less than 25")
# Your code here
number = 100
is_greater_than_50 = number > 50
is_less_than_25 = number < 25
result = is_greater_than_50 or is_less_than_25
print(f"Number: {number}")
print(f"Is greater than 50: {is_greater_than_50}")
print(f"Is less than 25: {is_less_than_25}")
print(f"Both conditions: {result}")
print("-" * 50)
# Out:
# Question 5: Check if 100 is greater than 50 or less than 25
# Number: 100
# Is greater than 50: True
# Is less than 25: False
# Both conditions: True
# --------------------------------------------------

# %%
# Question 6: Check if 0 is falsy in Python
print("\nQuestion 6: Check if 0 is falsy in Python")
# Your code here
number = 0
result = bool(number)
print(f"Number: {number}")
print(f"Is: {result}")
print("-" * 50)
# Out:
# Question 6: Check if 0 is falsy in Python
# Number: 0
# Is: False
# --------------------------------------------------

# %%
# Question 7: Check if empty string "" is falsy in Python
print("\nQuestion 7: Check if empty string '' is falsy in Python")
# Your code here
string = ""
result = bool(string)
print(f"String: {string}")
print(f"Is: {result}")
print("-" * 50)
# Out:
# Question 7: Check if empty string '' is falsy in Python
# String:
# Is: False
# --------------------------------------------------

# %%
# Question 8: Check if 42 is truthy in Python
print("\nQuestion 8: Check if 42 is truthy in Python")
# Your code here
number = 42
result = bool(number)
print(f"Number: {number}")
print(f"Is: {result}")
print("-" * 50)
# Out:
# Question 8: Check if 42 is truthy in Python
# Number: 42
# Is: True
# --------------------------------------------------

# %%
# Question 9: Check if 10 is between 5 and 15 (inclusive)
print("\nQuestion 9: Check if 10 is between 5 and 15 (inclusive)")
# Your code here
number = 10
is_between_5_and_15 = number >= 5 and number <= 15
print(f"Number: {number}")
print(f"Is between 5 and 15: {is_between_5_and_15}")
print("-" * 50)
# Out:
# Question 9: Check if 10 is between 5 and 15 (inclusive)
# Number: 10
# Is between 5 and 15: True
# --------------------------------------------------

# %%
# Question 10: Check if 3.14 is greater than 3 and less than 4
print("\nQuestion 10: Check if 3.14 is greater than 3 and less than 4")
# Your code here
number = 3.14
is_greater_than_3 = number > 3
is_less_than_4 = number < 4
result = is_greater_than_3 and is_less_than_4
print(f"Number: {number}")
print(f"Is greater than 3: {is_greater_than_3}")
print(f"Is less than 4: {is_less_than_4}")
print(f"Both conditions: {result}")
print("-" * 50)
# Out:
# Question 10: Check if 3.14 is greater than 3 and less than 4
# Number: 3.14
# Is greater than 3: True
# Is less than 4: True
# Both conditions: True
# --------------------------------------------------
